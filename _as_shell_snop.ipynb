# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/bakup/NZ/Work/smop/
# %ls
# Out:
# /content/gdrive/MyDrive/bakup/NZ/Work/smop
# _as_shell_snop.ipynb

# %%
# !git clone https://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@github.com/zzyydtc/smop.git
# Out:
# Cloning into 'smop'...
# remote: Enumerating objects: 7713, done.
# remote: Total 7713 (delta 0), reused 0 (delta 0), pack-reused 7713
# Receiving objects: 100% (7713/7713), 22.74 MiB | 8.09 MiB/s, done.
# Resolving deltas: 100% (4060/4060), done.

# %%
# !git log --oneline --graph
# Out:
# * bdad96b (HEAD -> master, origin/master, origin/HEAD) wip
# *   3505f96 merged
# |\
# | * fe7098f (tag: 0.41) 0.41
# | * bb8186e 0.41
# | * 34c9c8d wip
# | * daac1f2 cleanup
# * | 9c0f9a9 0.41-beta
# * | c31171b Release candidate 0.41
# * | 844034e wip
# * | 13e9a1a INSTALL
# * | c37c1e7 Ported to python3
# |/
# *   41faaba (tag: 0.40) wip
# |\
# | * 245d9c8 py3
# | * aac946d wip
# | * ad875db wip
# | * 9a34ba8 wip
# | * 12ae0ab INSTALL
# | * b157d02 I think missing version.py is fixed now
# | * c094d63 I think missing version.py is fixed now
# | * c0d2f8a py3 wip
# | * 2e0443e ported to py3
# | * 1a56eed ported to py3
# * | 4e0dcd9 wip
# * | 783ca3a wip
# |/
# * ba1f510 (tag: remote) works
# * d2ef186 works
# * 5833cd6 works
# * cccbbc5 works
# * d7ae6db resolve is a binary predicate now
# * a3c6dd4 WIP
# * 2c3a146 use =. instead of let
# * ac40bcf resolve
# * acf2d2e typo
# * 4df266b works
# * 2da5b8a WIP resolve/lhs_resolve
# * 6c2dc79 WIP resolve/lhs_resolve
# ...

# %%
# !git diff --stat

# %%
# !git add *.ipynb
# !git config --global user.email "mcob357777@gmail.com"
# !git config --global user.name "Mike Cob"
# !git commit -m "update as_shell name"

# !git push
